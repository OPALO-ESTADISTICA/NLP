# %% [markdown]
# ## Propósito
#
# La recolección de datos es una tarea crítica y de suma importancia para los analístis de datos. En algunos casos estos datos son de difícil acceso o de fuentes diversas, como internet, donde sería bastante tedioso extraer la información de manera manual.
#
# El propósito del presente cuaderno es extraer datos de páginas web en un ejercicio sencillo de **web scrapping** usando la librería de Python `BeautifulSoup` y elementos básicos de HTML (Hypertext Markup Language).

# %%
#Librerías necesarias para web-scrapping básico

from IPython.core.display import HTML
from bs4 import BeautifulSoup
from IPython.display import IFrame
import urllib # librería necesaria para acceder a los sitios web
import pandas as pd # Se usará para almacenar información de los sitios Web

# %% [markdown]
# ## HTML
#
# HTML es un lenguaje de marcado empleado para la construcción de páginas web y aplicaciones;nosotros constantemente estamos en contacto con ella cada vez que navegamos por internet. Algunos puntos claves a tener en cuenta al trabajar con HTML son:
#
# 1. HTML es tradicionalmente usado en la construcción de sitios web estáticos (sin interacción)
# 2. HTML usa una estructura anidada con etiquetas para indicar como mostrar el contenido
# 3. HTML puede ser integrado con otros leguanjes de programación
# 5. HTML puede ser creado usando cualquier editor de texto

# %% [markdown]
# Algunas de las etiquetas más populares, o útiles son:
#
# 1. < html > Indica que el sitio web esta escrito en formato HTML
# 2. < head > Encabezado
# 3. < title > Título en la barra de herramientas cuando es añadida a favoritos
# 4. < body > Define el bloque cuerpo del sitio web, el cuál muestra el contenido del sitio web
# 5. < p > Defines un párrafo que contiene texto que se le mostrará al ususario
# 6. < a > Define un hipervénculo
# 7. < h1 > Define un título de primer nivel
# 8. < h2 > Define un título de segundo nivel
# 9. < br > Define salto de línea
#
# A continuación se muestra un ejemplo de estas etiquetas y como se verían

# %%
custom_html_doc = """
<html>
<head>
<title>HTML Page Title</title>
</head>
<h1> Encabezado: Título de primer nivel</h1>
<br>
<h2> Título de segundo nivel</h2>
<body>
<p class="title"><b>Párrafo: Noticias</b></p>
<p class="story"> Algunas noticias de las últimas semanas son
<a href="https://www.bbc.com/news/av/world-us-canada-51230018" target="_blank" class="stock" id="link1">DUK</a>,
<a href="https://https://www.bbc.com/news/world-us-canada-59006604" target="_blank" class="stock" id="link2">D</a>,
<a href="https://finance.yahoo.com/quote/exc/" target="_blank" class="stock" id="link3">EXC</a>,
<a href="https://finance.yahoo.com/quote/nee/" target="_blank" class="etf" id="link4">NEE</a>,
<a href="https://finance.yahoo.com/quote/so/" target="_blank" class="stock" id="link5">SO</a>,
presentadas por hipervínculos.</p>
<p class="details">Final del documento.</p>
"""

# %%
HTML(custom_html_doc)
# Out:
# <html>
# <head>
# <title>HTML Page Title</title>
# </head>
# <h1> Encabezado: Título de primer nivel</h1>
# <br>
# <h2> Título de segundo nivel</h2>
# <body>
# <p class="title"><b>Párrafo: Noticias</b></p>
# <p class="story"> Algunas noticias de las últimas semanas son
# <a href="https://www.bbc.com/news/av/world-us-canada-51230018" target="_blank" class="stock" id="link1">DUK</a>,
# <a href="https://https://www.bbc.com/news/world-us-canada-59006604" target="_blank" class="stock" id="link2">D</a>,
# <a href="https://finance.yahoo.com/quote/exc/" target="_blank" class="stock" id="link3">EXC</a>,
# <a href="https://finance.yahoo.com/quote/nee/" target="_blank" class="etf" id="link4">NEE</a>,
# <a href="https://finance.yahoo.com/quote/so/" target="_blank" class="stock" id="link5">SO</a>,
# presentadas por hipervínculos.</p>
# <p class="details">Final del documento.</p>

# %% [markdown]
# ## Uso de BeautifulSoup para navegar en documentos tipo HTML
#
# BeautifulSoup es una librería de Python que transforma los documentos HTML en una estructura de árbol navegable. Es importante y útil para hacer que los documentos de HTML se puedan programar y analizar automáticamente. Su propósito es ofrecer una variedad de formas para buscar, editar y extraer información en documentos HTML

# %% [markdown]
# html.parse es la opción estándar para analizar una cadena de texto en HTML, igualmente, prettify() muestra la cadena analizada con la indentación incluida, lo que nos muestra como es la estructura que contemple BeautifulSoup

# %%
# Uso de html.parser para convertir el documento en una estructura de datos de BeautifulSoup
soup = BeautifulSoup(custom_html_doc, 'html.parser')

# Imprimir la estructura incluyendo la indentación
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    HTML Page Title
#   </title>
#  </head>
#  <h1>
#   Encabezado: Título de primer nivel
#  </h1>
#  <br/>
#  <h2>
#   Título de segundo nivel
#  </h2>
#  <body>
#   <p class="title">
#    <b>
#     Párrafo: Noticias
#    </b>
#   </p>
#   <p class="story">
#    Algunas noticias de las últimas semanas son
#    <a class="stock" href="https://www.bbc.com/news/av/world-us-canada-51230018" id="link1" target="_blank">
#     DUK
#    </a>
#    ,
#    <a class="stock" href="https://https://www.bbc.com/news/world-us-canada-59006604" id="link2" target="_blank">
#     D
#    </a>
#    ,
#    <a class="stock" href="https://finance.yahoo.com/quote/exc/" id="link3" target="_blank">
#     EXC
#    </a>
#    ,
#    <a class="etf" href="https://finance.yahoo.com/quote/nee/" id="link4" target="_blank">
#     NEE
#    </a>
#    ,
#    <a class="stock" href="https://finance.yahoo.com/quote/so/" id="link5" target="_blank">
#     SO
#    </a>
#    ,
# presentadas por hipervínculos.
#   </p>
#   <p class="details">
#    Final del documento.
#   </p>
#  </body>
# </html>

# %%
# la variable soup ya es una estructura de datos de BeautifulSoup, por lo que se pueden aplicar algunos métodos.

tag = soup.a   # Muestra los elemento con la etiqueta a. Por defecto solo toma el primero

print(tag)
type(tag)
# Out:
# <a class="stock" href="https://www.bbc.com/news/av/world-us-canada-51230018" id="link1" target="_blank">DUK</a>
# bs4.element.Tag

# %%
print("Tag's name: ", tag.name) #Nombre de la etiqueta.
print("Tag's text: ", tag.text) #Texto embebido en la etiqueta.
print("Tag's parent name: ", tag.parent.name) #Etiqueta padre.
# Out:
# Tag's name:  a
# Tag's text:  DUK
# Tag's parent name:  p

# %% [markdown]
# Una etiqueta puede contener más de un atributo. Se puede acceder a ellos usando el método `attrs`

# %%
# Mostrar atributos
print(tag.attrs)
# Out:
# {'href': 'https://www.bbc.com/news/av/world-us-canada-51230018', 'target': '_blank', 'class': ['stock'], 'id': 'link1'}

# %% [markdown]
# ### Extrar todas las etiquetas de un archivo
#
# Anteriormente se mostró que era posible acceder a los elementos de una etiqueta, sin embargo solo se regresaba el primero de ellos. Para dar solución a este percance se puede usar la función `find_all`

# %%
print(soup.find_all("a"))
# Out:
# [<a class="stock" href="https://www.bbc.com/news/av/world-us-canada-51230018" id="link1" target="_blank">DUK</a>, <a class="stock" href="https://https://www.bbc.com/news/world-us-canada-59006604" id="link2" target="_blank">D</a>, <a class="stock" href="https://finance.yahoo.com/quote/exc/" id="link3" target="_blank">EXC</a>, <a class="etf" href="https://finance.yahoo.com/quote/nee/" id="link4" target="_blank">NEE</a>, <a class="stock" href="https://finance.yahoo.com/quote/so/" id="link5" target="_blank">SO</a>]

# %%
for tag in soup.find_all("a"):
    print(tag["href"])
# Out:
# https://www.bbc.com/news/av/world-us-canada-51230018
# https://https://www.bbc.com/news/world-us-canada-59006604
# https://finance.yahoo.com/quote/exc/
# https://finance.yahoo.com/quote/nee/
# https://finance.yahoo.com/quote/so/

# %% [markdown]
# ## Importación de sitios web para analizar

# %%
# Scrape data from website
site_url = 'https://www.bbc.com/news/world-us-canada-59006604'
r = urllib.request.urlopen(site_url)
site_content = r.read().decode('utf-8-sig')

# Saving scraped HTML to .html file (for later processing)
with open('saved_page.html', 'w') as f:
    f.write(site_content)

# Use html.parser to create soup
s = BeautifulSoup(site_content, 'html.parser')

# %%
print(s.prettify()[:50]) # Solamente mostrar una porción del documento
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-GB">

# %%
# Determinar el número de ocurrencias de una etiqueta en el documento. Se almacena como un diccionario

tag_list = []
for tag in s.find_all():
    tag_list.append(tag.name)

tag_count_list = {}
for tag in tag_list:
    if tag in tag_count_list:
        tag_count_list[tag] = tag_count_list[tag] + 1
    else:
        tag_count_list[tag] = 1
        
tag_count_list
# Out:
# {'html': 1,
#  'head': 1,
#  'meta': 30,
#  'title': 1,
#  'link': 6,
#  'script': 48,
#  'style': 2,
#  'body': 1,
#  'div': 220,
#  'header': 2,
#  'nav': 3,
#  'a': 104,
#  'span': 154,
#  'svg': 23,
#  'path': 23,
#  'ul': 13,
#  'li': 94,
#  'button': 4,
#  'main': 1,
#  'article': 1,
#  'h1': 1,
#  'dl': 4,
#  'dt': 4,
#  'dd': 4,
#  'time': 1,
#  'p': 30,
#  'b': 1,
#  'iframe': 1,
#  'i': 2,
#  'aside': 4,
#  'h2': 5,
#  'noscript': 10,
#  'img': 10,
#  'footer': 1}

# %%
s.a.attrs
# Out:
# {'href': 'https://www.bbc.com',
#  'class': ['ssrcss-6qes9f-NavigationLink-LogoLink', 'eki2hvo11']}

# %%
url = "https://www.eltiempo.com/"
doc = urllib.request.urlopen(url).read()
doc = doc.decode('utf-8-sig')

# %%
soup = BeautifulSoup(doc, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script async="" type="text/javascript">
#    var _sf_startpt=(new Date()).getTime()
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(24),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){j++,L=y.hash,this[u]=x.now()}function o(){j--,y.hash!==L&&i(0,!0);var t=x.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=x.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,x=t("loader");if(w[v]&&x.xhrWrappable){var g=t(10),b=t(11),E=t(8),R=t(6),O=t(13),C=t(7),P=t(14),T=t(9),N=t("ee"),S=N.get("tracer");t(16),x.features.spa=!0;var L,j=0;N.on(u,r),N.on(p,r),N.on(d,o),N.on(l,o),N.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),C.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),g.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),T.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(N,"xhr-resolved"),a(N,"xhr-done"),a(C,m+s),a(C,m+"-done"),a(T,"new-jsonp"),a(T,"jsonp-end"),a(T,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,j>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",y="pushState",x=t("loader");x.features.stn=!0,t(8);var g=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof g&&(this.bstStart=x.now())}),o.on(v,function(t,e){var n=t[0];n instanceof g&&i("bst",[n,e,this.bstStart,x.now()])}),a.on(m,function(t,e,n){this.bstStart=x.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,x.now(),this.bstType])}),s.on(m,function(){this.bstStart=x.now()}),s.on(v,function(t,e){i(w,[e,this.bstStart,x.now(),"requestAnimationFrame"])}),o.on(y+l,function(t){this.time=x.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performa ...
# ;NREUM.loader_config={accountID:"2420843",trustKey:"2420843",agentID:"582566107",licenseKey:"ae648b7581",applicationID:"582560613"}
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"ae648b7581",applicationID:"582560613",sa:1}
#   </script>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="telephone=no" name="format-detection">
#    <meta content="Casa Editorial El Tiempo" name="author">
#     <meta content="News" name="genre"/>
#     <meta content="Colombia" name="geo.placename"/>
#     <meta content="4.570868;-74.297333" name="geo.position"/>
#     <meta content="CO" name="geo.region"/>
#     <meta content="notranslate" name="google"/>
#     <meta content="4.570868, -74.297333" name="ICBM"/>
#     <meta content="spanish" name="language"/>
#     <meta content="summary" name="twitter:card"/>
#     <meta content="@ELTIEMPO" name="twitter:site"/>
#     <meta content="@ELTIEMPO" name="twitter:creator"/>
#     <meta content="Noticias Principales de Colombia y el Mundo - El Tiempo" name="twitter:title"/>
#     <meta content="Noticias Principales de Colombia y El Mundo: Últimas noticias en deportes, economía, política y tecnología. Manténgase informado sobre las noticias de Colombia en EL TIEMPO.COM." name="twitter:description"/>
#     <meta content="/images/compartir.jpg?2110192010" name="twitter:image"/>
#     <link href="/images/compartir.jpg?2110192010" rel="image_src"/>
#     <link href="https://www.eltiempo.com/" rel="canonical"/>
#     <meta content="Noticias Principales de Colombia y El Mundo: Últimas noticias en deportes, economía, política y tecnología. Manténgase informado sobre las noticias de Colombia en EL TIEMPO.COM." name="description"/>
#     <meta content="noticias principales, noticias colombia, noticias, ultimas noticias, periodico, díario, clasificados, prensa, el tiempo,noticias nacionales, noticias de hoy, actualidad" name="keywords"/>
#     <meta content="noticias principales, noticias colombia, noticias, ultimas noticias, periodico, díario, clasificados, prensa, el tiempo,noticias nacionales, noticias de hoy, actualidad" name="news_keywords"/>
#     <meta content="index, follow" name="robots">
#      <meta content="website" property="og:type">
#       <meta content="Noticias Principales de Colombia y el Mundo - El Tiempo" property="og:title">
#        <meta content="Noticias Principales de Colombia y El Mundo: Últimas noticias en deportes, economía, política y tecnología. Manténgase informado sobre las noticias de Colombia en EL TIEMPO.COM." property="og:description"/>
#        <meta content="https://www.eltiempo.com/" property="og:url"/>
#        <meta content="/images/compartir.jpg?2110192010" property="og:image"/>
#        <meta content="El Tiempo" property="og:site_name"/>
#        <meta content="100002279652972" property="fb:admins"/>
#        <meta content="es_CO" property="og:locale"/>
#        <meta content="es_CO" property="og:locale:alternate"/>
#        <title>
#         Noticias Principales de Colombia y el Mundo - Noticias - ELTIEMPO.COM
#        </title>
#        <link href="/css/ndesktop-home.css?2110192010" rel="stylesheet">
#         <link as="font" crossorigin="" href="/css/fonts/open_sans/OpenSans-Semibold.woff2" rel="preload" type="font/woff2"/>
#         <link as="font" crossorigin="" href="/css/fonts/open_sans/OpenSans.woff2" rel="preload" type="font/woff2"/>
#         <link as="font" crossorigin="" href="/css/fonts/open_sans/OpenSans-Bold.woff2" rel="preload" type="font/woff2"/>
#         <link as="font" crossorigin="" href="/css/fonts/et-icon/et-icon-141020.woff2" rel="preload" type="font/woff2"/>
#         <link as="font" crossorigin="" href="/css/fonts/roboto_slab/robotoslab-bold-webfont.woff2" rel="preload" type="font/woff2"/>
#         <link as="font" crossorigin="" href="/css/fonts/roboto_slab/robotoslab-regular-webfont.woff2" rel="preload" type="font/woff2"/>
#         <link as="font" crossorigin="" href="/css/fonts/open_sans/OpenSans-ExtraBold.woff2" rel="preload" type="font/woff2"/>
#         <link as="font" crossorigin="" href="/css/fonts/et_icon_2019/icon-et-2019.woff2" rel="preload" type="font/woff2"/>
#         <script type="text/javascript">
#          var sas_siteId = 22171;
# var sas = sas || {};
# sas.cmd = sas.cmd || [];
# sas.cmd.push(function() {
# sas.setup({ networkid: 484, domain: "//ads.eltiempo.co", async: true });
# });
#         </script>
#         <script src="/js/desktoplib.js?2110192010" type="text/javascript">
#         </script>
#         <script async="" src="//cdn.tinypass.com/api/tinypass.min.js" type="text/javascript">
#         </script>
#         <script type="text/javascript">
#          tp = window["tp"] || [];
# function onCheckoutClose(event) {
# /* Default behavior is to refresh the page on successful checkout */
# if (event && event.state == "checkoutCompleted") {
# location.reload();
# }
# }
# /* Callback executed when a user must login */
# function onLoginRequired() {
# return false;
# }
# /* Callback executed if external checkout has been completed successfully */
# function onExternalCheckoutComplete(event) {
# /* Default behavior is to refresh the page on successful checkout */
# location.reload();
# }
# tp.push(["setAid", '3ST2fSyHpu']);
# tp.push(["setCxenseSiteId", "1139721983214147178"])
# tp.push(["setEndpoint", 'https://buy.tinypass.com/api/v3']);
# tp.push(["setUseTinypassAccounts", false]);
# tp.push(["setUsePianoIdUserProvider", false]);
# tp.push(["setUsePianoIdLiteUserProvider", true]);
# /* checkout related events */
# tp.push(["addHandler", "checkoutClose", onCheckoutClose]);
# /* user login events */
# tp.push(["addHandler", "loginRequired", onLoginRequired]);
# /* external checkout related events */
# tp.push(["addHandler", "checkoutComplete", function(s) {
# setTimeout(function() {
# window.location.replace("/")
# }, 5000)
# }])
#         </script>
#         <script>
#          //esp
# document.cookie = "__adblocker=; expires=Thu, 01 Jan 1970 00:00:00 GMT; path=/";
# var setNptTechAdblockerCookie = function(adblocker) {
# var d = new Date(); d.setTime(d.getTime() + 60 * 5 * 1000);
# document.cookie = "__adblocker=" + (adblocker ? "true" : "false") + "; expires=" + d.toUTCString() + "; path=/";
# };
# var script = document.createElement("script");
# script.setAttribute("async", true);
# script.setAttribute("src", "//www.npttech.com/advertising.js");
# script.setAttribute("onerror", "setNptTechAdblockerCookie(true);");
# document.getElementsByTagName("head")[0].appendChild(script);
#         </script>
#         <script defer="defer" type="text/javascript">
#          var textChars = 'Por favor no ingreses más de {0} caracteres.';
# var textSpecialChars = 'No se permiten caracteres especiales.';
# var textSpecialChars2 = 'Solo se permiten letras, números, comas, puntos y espacios en blanco.';
# var textNumbers = 'No se permiten números.';
# var textCharacters = 'Solo se permiten números.';
# var textEmail = 'Este no es un correo electrónico válido.';
# var textStartsWithZero = 'El número no puede empezar con cero.';
# var textOnlyLettersAndNumbersNotWhiteSpaces = 'Solo se permiten letras y números sin espacios en blanco.';
# var textOnlyLettersAndNumbersWithWhiteSpaces = 'Solo se permiten letras y números con espacios en blanco.';
# var nameRules = {"required":true,"minlength":1,"maxlength":100,"onlyLettersAndNumbersWithWhiteSpaces":true};
# var userRules = {"required":true,"noCharacters":true,"minlength":6,"maxlength":20};
# var emailRules = {"required":true,"email":true,"noEmail":true,"minlength":1,"maxlength":100};
# var phoneNumberRules = {"required":true,"noCharacters":true,"maxlength":10,"minlength":7,"noStartsWithZero":true};
# var messageRules = {"noSpecialChars2":true,"required":true,"minlength":10,"maxlength":1000};
# var privacyRules = {"required":true};
# var privacyPolicyRules = {"required":true};
# var messageRules2 = {"required":false,"maxlength":150};
# var nameMessage = {"required":"Debes ingresar tu nombre. Recuerda que \u00e9ste no puede tener n\u00fameros o caracteres especiales.","minlength":"\u00a1Al menos debes ingresar {0} caracteres!"};
# var emailMessage = {"required":"Ingresa tu correo electr\u00f3nico para continuar. Recuerda que debe estar bien escrito para poder continuar.","email":"Tu correo electr\u00f3nico debe tener un formato como nombre@dominio.com"};
# var messageMessage = {"required":"Escribe ac\u00e1 el error que encontraste para que podamos revisarlo. Gracias.","maxlength":"Por favor no ingreses m\u00e1s de {0} caracteres.","minlength":"Por favor ingresa m\u00e1s de {0} caracteres."};
# var nc = '4563da6f176be58ebd5c29ac27bdefe6';
# var s_account = "eltiempo";
# var wf_public_url = "https://www.eltiempo.com";
# var pautasSmart = {"desktop":{"recurso":{"push_down":21675,"barra_flotante":8941,"pre_home":29221,"robapagina_superior":9346,"film_strip":32365,"in_read":9343,"cuarto_robapagina":9608,"solapa":9639},"recurso_patrocinado":{"push_down":8932,"barra_flotante":17232,"pre_home":"","robapagina_superior":9344,"film_strip":39297,"in_read":9601,"cuarto_robapagina":44664,"solapa":9643}},"tablet":{"recurso":{"push_down":21675,"barra_flotante":8941,"pre_home":29221,"robapagina_superior":9346,"film_strip":32365,"in_read":9343,"cuarto_robapagina":9608,"solapa":9639},"recurso_patrocinado":{"push_down":8932,"barra_flotante":17232,"pre_home":"","robapagina_superior":9344,"film_strip":39297,"in_read":9601,"cuarto_robapagina":44664,"solapa":9643}},"mobile":{"recurso":{"catfish":8941,"robapagina_superior":9346,"in_read":9343,"banner_superior":21675,"pre_home":31430},"recurso_patrocinado":{"catfish":17232,"robapagina_superior":9344,"in_read":9601,"banner_superior":8932,"pre_home":""}}};
# if (!("sas_pageId" in window)) {
# sas_pageId = '';
# }
# if (!("sas_target" in window)) {
# sas_target = 'home';
# }
# var ssoClient = 'eltiempodigital';
# var ssoMiSuscripcionPath = 'https://www.eltiempo.com/zona-usuario/mi-suscripcion';
# var ssoSuscribirmePath = 'https://seg.eltiempo.com/suscripciones/impreso/eltiempodigital?utm_source=Autopauta&utm_medium=eltiempo_prp&utm_campaign=AutoPautaFija&utm_content=BotonHomeHeader';
# //var ssoSuscribirmePath = 'https://seg.eltiempo.com/suscripciones'
# var ssoSuscribirmeDigitalPath = 'https://www.eltiempo.com/suscripcion-digital';
# var ssoPortal = 'seg.eltiempo.com';
# var ssoProtocol = 'https';
# var ssoVerify = 'server/verify-login/';
# var ssoVerifyComplement = '/code/basic/';
# var liftigniter_number = '8';
# //Variables para dmp
# var deviceXalok = 'desktop';
# var dmpCampaigns = {"segmento1":{"audiencia":355181,"campana":304553,"numero_campana":1,"hash":"Aa9K0aK0I1E0jwPuSnixSiUG7Uxb2DfS5AlAvRbmNC8%3D","secciones":["justicia","politica","bogota","opinion","colombia","tecnosfera"]},"segmento2":{"audiencia":355189,"campana":304554,"numero_campana":2,"hash":"Q5PKJWzAM3qixYEd2AEFSIFzg8dHRrwZff%2BPSqJJbyI%3D","secciones":["politica","vida","justicia","economia","mundo","deportes"]},"segmento3":{"audiencia":355191,"campana":303509,"numero_campana":3,"hash":"hUyTg2Ik%2B0CX3ltsRahcS4S9wt3vKgqRbyzE2oaAAP8%3D","secciones":["justicia","economia","vida","politica","colombia","tecnosfera"]},"segmento4":{"audiencia":361200,"campana":304559,"numero_campana":4,"hash":"hCNNmr%2FWJ%2FsVAMIlKAi0htYroKSt6HV26cm6gZpMFbE%3D","secciones":["economia","tecnosfera","vida","bogota","deportes","colombia"]},"segmento5":{"audiencia":428587,"campana":350483,"numero_campana":5,"hash":"Z4Lzm8NgVsYDnxtiC2YTGYs6DdS4WLmBIPiHD%2F2Kuw8%3D","secciones":["economia","tecnosfera","politica","justicia"]},"segmento6":{"audiencia":428909,"campana":362238,"numero_campana":6,"hash":"MBy3Ks6dLaQI5AxMkwn9fZd4yFWXD5w1zZ3c2rJlmE0%3D","secciones":["opinion"]},"segmento7":{"audiencia":428906,"campana":362237,"numero_campana":7,"hash":"%2Fim6k3vqRhcciGuGPEAYAqa2z3AZEScTL2X3NagwRNM%3D","secciones":["deportes"]},"segmento8":{"audiencia":428907,"campana":362236,"numero_campana":8,"hash":"e%2BJsjjtaMLQzrj%2BsGci12aYf5Y5IosdxvK89gVidtIs%3D","secciones":["tecnosfera"]}};
# var dmpArticleNumber = 13;
# //variables para profiling
# var profiling = {"coachmark":{"time":1543594585,"name":"coachmark_time_et"},"feed":{"section":"\/var\/www\/eltiempo\/app\/public\/..\/..\/web\/files\/sections.json","content":"\/var\/www\/eltiempo\/app\/public\/..\/..\/web\/files\/content_feed.json"},"sidebar":{"sidebar_automation_time":60000,"sidebar_automation_enable":0}};
# var profilingApiKey = '0f269180c539c7efa10633cda8a79cbb';
# var contentProfilingUrl = 'https://servicios.eltiempo.com/content-profiling-api/v1';
# var profiling_special_section= ["revistas","bocas","carrusel","bogota","lecturas"];
# var profiling_coachmark_status = 'inactive'
# var profilingQuantityResources = 120 //variable encargada de lamacenar la maxima cantidad de noticias a presentar
# var profilingQuantityPerSection = 120 //variable encargada de almacenar la cantidad de secciones seguidas
# var profilingQuantityResourcesHome = 15 //variable encargada de lamacenar la maxima cantidad de noticias a presentar en el home
# var tokenSession = getTokenSession();
# // OneSignal
# var oneSignalAppId = "d8e81a0b-276a-4763-8cef-bcd5df9a51a5";
# var oneSignalSafariAppId = "web.onesignal.auto.47a2f439-afd3-4bb7-8cdd-92cc4f5ee46c";
# var notifyButtonEnable = true;
# var recommendationMotorUrl = "https://recomendador.eltiempo.com/recommendation";
# // lazyload
# var lazyloadDefault = '...'
# //google analitycs
# var google_analitycs_ua = 'UA-118090425-1'
# // tipos de suscripcion
# var suscription_types = {"IG":"suscriptor-impreso","DS":"suscriptor-digital"}
# window.eltiempo_ads_config = {"desktop":{"home":{"sas_pageId":152163},"article":{"sas_pageId":152162},"section":{"sas_pageId":152170},"comercial_article":{"sas_pageId":181947}},"tablet":{"home":{"sas_pageId":152163},"article":{"sas_pageId":152162},"section":{"sas_pageId":152170},"comercial_article":{"sas_pageId":181947}},"mobile":{"home":{"sas_pageId":374008},"article":{"sas_pageId":529862},"section":{"sas_pageId":374009},"comercial_article":{"sas_pageId":667552}}}
#         </script>
#         <script defer="defer" src="/js/global_desktop_libraries.js?2110192010" type="text/javascript">
#         </script>
#         <script defer="defer" src="/js/global_desktop.js?2110192010" type="text/javascript">
#         </script>
#         <script defer="defer" src="/js/desktop_home_public.js?2110192010" type="text/javascript">
#         </script>
#         <script>
#          var digitalData = digitalData || {};
# digitalData = {
# page: {
# pageName: pageName(),
# channel: channel(),
# day: day(),
# hour: hour(),
# section: section(),
# subsection: subsection(),
# referrer: referrer(),
# contentType: contentType(),
# userName: getUserName(),
# weekday: weekday()
# }
# };
#         </script>
#         <!-- Google Analytic (gtm.js) -->
#         <script>
#          (function(w,d,s,l,i){
# w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});
# var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
# j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WG4KTGL');
#         </script>
#         <!-- Google Tag Manager Optimizado-->
#         <script>
#          (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PLVTDKZ');
#         </script>
#         <div class="module">
#          <div class="" id="p87-m278-277-279">
#           <!-- 11.16 2018 -->
#          </div>
#         </div>
#         <script async="" type="text/javascript">
#          /** CONFIGURATION CHARTBEAT **/
# var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});
# _sf_async_config.uid = 50648; //CHANGE THIS
# _sf_async_config.domain = 'eltiempo.com'; //CHANGE THIS
# _sf_async_config.useCanonical = true;
# _sf_async_config.lazyLoadSrcsetAttribute = 'data-original';
# _sf_async_config.flickerControl = false;
#         </script>
#         <script async="" src="//static.chartbeat.com/js/chartbeat_mab.js">
#         </script>
#         <script>
#          //variable con url para motor de recomendacion
# var recomendationUrl = 'https://recomendador.eltiempo.com/recommendation'
#         </script>
#         <script defer="defer" src="/js/global_general_home.js?2110192010" type="text/javascript">
#         </script>
#         <script type="application/ld+json">
#          {
# "@context": "https://schema.org",
# "@type": "BreadcrumbList",
# "itemListElement":
# [
# {
# "@type": "ListItem",
# "position": 1,
# "item":
# {
# "@id": "https://www.eltiempo.com/",
# "name": "Inicio"
# }
# }
# ]
# }
#         </script>
#         <link href="/favicon.ico" rel="shortcut icon">
#          <link href="/favicon-32x32.png" rel="apple-touch-icon" sizes="32x32"/>
#          <link href="/favicon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#          <link href="/favicon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#          <script type="application/ld+json">
#           {
# "@context": "https://schema.org",
# "@type": "WebSite",
# "url": "https://www.eltiempo.com/",
# "potentialAction": {
# "@type": "SearchAction",
# "target": "https://www.eltiempo.com/buscar?q={search_term_string}",
# "query-input": "required name=search_term_string"
# }
# }
#          </script>
#          <script>
#           !function(a){var e="https://s.go-mpulse.net/boomerang/",t="addEventListener";if("True"=="True")a.BOOMR_config=a.BOOMR_config||{},a.BOOMR_config.PageParams=a.BOOMR_config.PageParams||{},a.BOOMR_config.PageParams.pci=!0,e="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="D72D5-WUQSN-PLC23-RDC47-L9SU5",function(){function n(e){a.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!a.BOOMR||!a.BOOMR.version&&!a.BOOMR.snippetExecuted){a.BOOMR=a.BOOMR||{},a.BOOMR.snippetExecuted=!0;var i,_,o,r=document.createElement("iframe");if(a[t])a[t]("load",n,!1);else if(a.attachEvent)a.attachEvent("onload",n);r.src="javascript:void(0)",r.title="",r.role="presentation",(r.frameElement||r).style.cssText="width:0;height:0;border:0;display:none;",o=document.getElementsByTagName("script")[0],o.parentNode.insertBefore(r,o);try{_=r.contentWindow.document}catch(O){i=document.domain,r.src="javascript:var d=document.open();d.domain='"+i+"';void(0);",_=r.contentWindow.document}_.open()._l=function(){var a=this.createElement("script");if(i)this.domain=i;a.id="boomr-if-as",a.src=e+"D72D5-WUQSN-PLC23-RDC47-L9SU5",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(a)},_.write("<bo"+'dy onload="document._l();">'),_.close()}}(),"".length>0)if(a&&"performance"in a&&a.performance&&"function"==typeof a.performance.setResourceTimingBufferSize)a.performance.setResourceTimingBufferSize();!function(){if(BOOMR=a.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var e=""=="true"?1:0,t="",n="faaajbchq3cxajqacqmyiaaaabqxrnt4-f-711646a98-clienttons-s.akamaihd.net",i="false"=="true"?2:1,_={"ak.v":"32","ak.cp":"541205","ak.ai":parseInt("584384",10),"ak.ol":"0","ak.cr":19,"ak.ipv":6,"ak.proto":"http/1.1","ak.rid":"163838e","ak.r":35814,"ak.a2":e,"ak.m":"dscf","ak.n":"essl","ak.bpcip":"2800:484:4786:c570::","ak.cport":62327,"ak.gh":"104.75.171.31","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1635300988","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"45","ak.dpoabenc":"","ak.tf":i};if(""!==t)_["ak.ruds"]=t;var o={i:!1,av:function(e){var t="http.initiator";if(e&&(!e[t]||"spa_hard"===e[t]))_["ak.feo"]=void 0!==a.aFeoApplied?1:0,BOOMR.addVar(_)},rv:function(){var a=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(a)}};BOOMR.plugins.AK={akVars:_,akDNSPreFetchDomain:n,init:function(){if(!o.i){var a=BOOMR.subscribe;a("before_beacon",o.av,null,null),a("onbeacon",o.rv,null,null),o.i=!0}return this},is_complete:function(){return!0}}}}()}(window);
#          </script>
#         </link>
#        </link>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="section-home home-new">
#   <!-- Google site tag (gtm.js) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WG4KTGL" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- Google Tag Manager (noscript) Optimizado -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PLVTDKZ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    var randNumber = Math.random();
# $.ajax({
# url: ssoProtocol + '://' + ssoPortal + '/api/user-bar/' + ssoClient /* + '/' + reqType */,
# data: {rfs: randNumber},
# dataType: 'json',
# xhrFields: {
# withCredentials: true
# },
# success: function (data) {
# console.log('piano barra')
# tp = window["tp"] || [];
# if (data && data.identity) {
# identity = data.identity;
# //se verifica si viene el jwt para piano y su respectivo envio
# if (identity.jwtToken && typeof tp !== 'undefined') {
# console.log('jwToken')
# tp.push(["setUsePianoIdLiteUserProvider", true ]);
# tp.push(["setExternalJWT", identity.jwtToken]);
# }
# if (identity.subscription) {
# console.log('piano suscriptor')
# //se agrega dato de suscripcion para envio a piano
# if (typeof tp !== 'undefined') {
# tp.push(['setCustomVariable', 'userSuscription', 'suscriptor'])
# // Se agrega modulo de My Account
# tp.push(["init", function() {
# tp.myaccount.show({
# displayMode: "inline",
# containerSelector: "#content-my-account-piano"
# });
# }]);
# }
# }
# }
# // se busca si es contenido premium
# var contentType = 'Estandar'
# // validacion general de json coninformacion
# if (typeof digitalData === 'object' && digitalData.hasOwnProperty('page') && typeof tp !== 'undefined') {
# // se busca autor
# if (digitalData.page.hasOwnProperty('autores') && digitalData.page.autores !== '') {
# tp.push(['setContentAuthor', digitalData.page.autores.replace('User', '')])
# } else {
# tp.push(['setContentAuthor', 'El tiempo'])
# }
# // se busca seccion
# if (digitalData.page.hasOwnProperty('section') && digitalData.page.section !== '') {
# tp.push(['setContentSection', digitalData.page.section])
# }
# // se busca subseccion
# if (digitalData.page.hasOwnProperty('subsection') && digitalData.page.subsection !== '') {
# tp.push(['setCustomVariable', 'subSection', digitalData.page.subsection])
# }
# // se busca fecha de creacion
# if (digitalData.page.hasOwnProperty('datePublishIso') && digitalData.page.datePublishIso !== '') {
# tp.push(['setContentCreated', digitalData.page.datePublishIso])
# tp.push(['setCustomVariable', 'contentCreated', digitalData.page.datePublishIso])
# }
# // se busca si es contenido premium
# if (digitalData.page.hasOwnProperty('categoryType') && digitalData.page.categoryType !== '') {
# if(digitalData.page.categoryType !== 'Seleccione una categoria'){
# contentType = digitalData.page.categoryType
# }
# tp.push(['setCustomVariable', 'premiumContent', contentType])
# }
# // se busca si esta el tipo contenido y si es de bbc
# if (digitalData.page.hasOwnProperty('contentType') && digitalData.page.contentType !== '') {
# if (digitalData.page.contentType.search('BBC') !== -1) {
# tp.push(['setContentIsNative', false])
# tp.push(['setCustomVariable', 'nativeContent', 0])
# }else {
# tp.push(['setContentIsNative', true])
# tp.push(['setCustomVariable', 'nativeContent', 1])
# }
# tp.push(['setCustomVariable', 'contentType', digitalData.page.contentType])
# }
# // se buscan tag del contenido
# if (digitalData.page.hasOwnProperty('tags') && digitalData.page.tags !== '') {
# tp.push(['setTags', digitalData.page.tags])
# }
# // se buscan id del contenido
# if (digitalData.page.hasOwnProperty('pageID') && digitalData.page.pageID !== '') {
# tp.push(['setCustomVariable', 'id', digitalData.page.pageID])
# }
# // se busca si es contenido cerrado premium
# if (digitalData.page.hasOwnProperty('premium') && digitalData.page.premium !== '') {
# tp.push(['setCustomVariable', 'closedContentPremium', digitalData.page.premium])
# }
# // se buscan titulo del contenido
# if (digitalData.page.hasOwnProperty('pageName') && digitalData.page.pageName !== '') {
# tp.push(['setCustomVariable', 'ContentTitle', digitalData.page.pageName])
# }
# // se busca si esta el nombre de usuario
# if (digitalData.page.hasOwnProperty('userName') && digitalData.page.userName !== false) {
# tp.push(['setCustomVariable', 'userName', digitalData.page.userName])
# }
# // se busca dia de la semana
# if (digitalData.page.hasOwnProperty('day') && digitalData.page.day !== '') {
# tp.push(['setCustomVariable', 'day', digitalData.page.day])
# }
# // se busca hora de la visita
# if (digitalData.page.hasOwnProperty('hour') && digitalData.page.hour !== '') {
# tp.push(['setCustomVariable', 'hour', digitalData.page.hour])
# }
# // se busca referrer de la visita
# if (digitalData.page.hasOwnProperty('referrer') && digitalData.page.referrer !== '') {
# tp.push(['setCustomVariable', 'referrer', digitalData.page.referrer])
# }
# //// se busca si el usuario es suscriptor
# if (digitalData.page.hasOwnProperty('userSuscription') && digitalData.page.userSuscription !== '') {
# tp.push(['setCustomVariable', 'userSuscription', digitalData.page.userSuscription])
# }
# //redirect para anonimo
# tp.p//redirect para anonimo
# tp.push(["addHandler", "loginRequired", function(params){
# //alert('El login es necesario, autenticate y continua con el proceso de compra')
# window.location.href = "/login";
# return false;
# }]);
# //evento usado para los temas de LTS
# tp.push(["addHandler", "experienceExecute", function (e) {
# //Obtenemos todos los eventos que traiga el excute
# var eventosLTS = e.result.events;
# //recorremos los eventos
# for (i = 0; i < eventosLTS.length; i++) {
# //obtenemos los nombres del modulo de cada evento
# var textoModulo = eventosLTS[i].eventModuleParams.moduleName;
# var palabra = String(textoModulo);
# //validamos si cada nombre del modulo contiene la palabra LTS
# if(palabra.includes("LTS")){
# //validamos si tiene un numero como string para determinar si es segmento o probabilidad
# var validacion = /\d/;
# if(validacion.test(palabra)){
# var probabilidad = palabra;
# }
# else{
# var segmento = palabra;
# }
# }
# //ID oferta A/B testing LP
# var templateID = String(eventosLTS[i].eventParams.templateId);
# if(templateID != "OTH4MQIZVJIX" && templateID != "undefined"){
# var templateIDABTest = templateID;
# //console.log("Template ID de Oferta A/B Test: ", templateIDABTest)
# }
# //ID ab test LTS y Meter estatico
# if(eventosLTS[i].eventType == "experienceExecute"){
# var variantName = eventosLTS[i].eventExecutionContext.splitTests[0].variantName;
# console.log("Variant Name Meter/LTS A/B Test: ", variantName);
# }
# //Contador Meter
# if(eventosLTS[i].eventType == "showOffer"){
# var meters = eventosLTS[i].eventExecutionContext.allMeters;
# for (j = 0; j < meters.length; j++) {
# if(meters[j].meterName == "MeterExperience"){
# var contadorMeter = meters[j].views;
# //console.log("Contador Meter Execute ", contadorMeter)
# }
# }
# }
# }
# //registramos los datos en el datalayer
# if(segmento || probabilidad || templateIDABTest || contadorMeter || variantName){
# dataLayer.push({
# 'event':'experienceExecute',
# 'segmentoLTX' : segmento,
# 'probabilidadLTX' : probabilidad,
# 'templateABtest' : templateIDABTest,
# 'variantNameLTSMeter' : variantName,
# 'contadorMeter' : contadorMeter
# });
# }
# }]);
# //meter
# //meter activo
# tp.push(["addHandler", "meterActive", function(meterData){
# /*console.log('Nombre meter activo', meterData.meterName )
# console.log('Conteo de meter activo', meterData.views )*/
# var metername = meterData.meterName;
# if(metername !="LTSMeterTest"){
# setTimeout(function(){
# dataLayer.push({
# 'event':'ga_Meter_Active',
# 'Tipo':'Active',
# 'Nombre_Meter': meterData.meterName,
# 'Contador_Meter': meterData.views,
# 'Contador_vistasRestantes': meterData.viewsLeft,
# 'Contador_limiteTotal': meterData.maxViews,
# 'Contador_totalViews': meterData.totalViews,
# 'Contador_incrementView': meterData.incremented
# });
# }, 1000);
# }
# }]);
# //meter vencido
# tp.push(["addHandler", "meterExpired", function(meterData){
# /*console.log('Nombre meter expirado', meterData.meterName )
# console.log('Conteo de expirado', meterData.views )*/
# var metername = meterData.meterName;
# if(metername !="LTSMeterTest"){
# setTimeout(function(){
# dataLayer.push({
# 'event':'ga_Meter_Expired',
# 'Tipo':'Expired',
# 'Nombre_Meter': meterData.meterName,
# 'Contador_Meter': meterData.views,
# 'Contador_vistasRestantes': meterData.viewsLeft,
# 'Contador_limiteTotal': meterData.maxViews,
# 'Contador_totalViews': meterData.totalViews,
# 'Contador_incrementView': meterData.incremented
# });
# }, 1000);
# }
# }]);
# //cuando se muestra un modal
# tp.push( [ "addHandler", "showTemplate", function (templateParams) {
# setTimeout(function(){
# dataLayer.push({
# 'event':'showTemplate',
# 'templateID': templateParams.templateId
# });
# }, 1000);
# }]);
# tp.push( [ "addHandler", "checkoutCustomEvent", function (event) {
# dataLayer.push({
# 'event':'clickTemplate',
# 'eventclickname' : event.eventName
# });
# }]);
# }
# tp.push(["init", function () {
# console.log('piano init')
# tp.enableGACrossDomainLinking(google_analitycs_ua);
# tp.experience.execute();
# }])
# }
# })
#   </script>
#   <div class="main-container" id="main-container">
#    <div class="module-free-html">
#     <div class="" id="p88-m823-1-824">
#      <style>
#       section.landing-paquetes-pro > .banner-blanco-mt-uno, section.landing-paquetes-pro > .banner-morado.bg1, section.landing-paquetes-pro > .banner-blanco-mt-50, .landing-renovacion #piano-digital-subscription-plan-pro-banner{ display: none; }
#      </style>
#     </div>
#     <div class="" id="p88-m829-2-830">
#      <!-- Hotjar Tracking Code for www.eltiempo.com -->
#      <script>
#       (function(h,o,t,j,a,r){
# h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
# h._hjSettings={hjid:2527580,hjsv:6};
# a=o.getElementsByTagName('head')[0];
# r=o.createElement('script');r.async=1;
# r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
# a.appendChild(r);
# })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
#      </script>
#     </div>
#     <div class="" id="p88-m835-3-836">
#      <!-- Cambio color bot&oacute;n $900 -->
#      <style>
#       #header_new .top-contenedor .top_bar .cliente li #suscribase-header,
# #header_new .top-contenedor .content-sections .suscribase-header:not(.usuario-suscriptor),#header_new .top-contenedor .top_bar .cliente li.login-bar .menu_noUser.toggable-menu .subscription-bar .btn_subscription
# {background:#daf926;}
# #suscribase-header .suscribase, #header_new .suscribase-header span {color: #000;}
# header .header_mobile .header_modulo_suscripcion a[href*="suscripcion-digital"].btn_suscribirme{
# background:#daf926 !important;
# }
# #header_new .top-contenedor .content-sections .suscribase-header.usuario-suscriptor{background: #27ae60;}
# #header_new .top-contenedor .content-sections .suscribase-header.usuario-suscriptor span{color: #fff}
#      </style>
#     </div>
#    </div>
#    <div class="ad_sas_pauta_desktop" id="sas_29221">
#    </div>
#    <div class="ad_sas_pauta_mobile" id="sas_29221">
#    </div>
#    <div class="ad_sas_pauta_desktop" id="sas_8941">
#    </div>
#    <div class="ad_sas_pauta_mobile" id="sas_8941">
#    </div>
#    <div class="ad_sas_pauta_tablet" id="sas_8941">
#    </div>
#    <div class="ad_sas_pauta_desktop" id="sas_21675">
#    </div>
#    <div class="ad_sas_pauta_tablet" id="sas_21675">
#    </div>
#    <div class="ads-before-header">
#     <div class="module-ads">
#      <div class="" id="p15871-m490-489-491">
#       <!-- NO BORRAR -->
#       <!-- <style>
# .contenido-exclusivo-icon *::before{
# content: none !important;
# }
# </style>
# -->
#      </div>
#      <div class="" id="p15871-m496-1-497">
#       <style>
#        .rutina { display:none; }
#       </style>
#      </div>
#      <div class="" id="p15871-m502-2-503">
#       <style>
#        .deportes-tablas .titular-tablas .tabs-tablas li#goleadores{
# display: none;
# }
# .deportes-tablas .titular-tablas .tabs-tablas li#descenso{
# display: none;
# }
#       </style>
#      </div>
#      <div class="" id="p15871-m508-3-509">
#       <style>
#        .mis-noticias-desactivado.multimedia-article header .top-contenedor .topbar5 {width: unset}
#       </style>
#      </div>
#      <div class="" id="p15871-m514-4-515">
#       <script type="text/javascript">
#        $(document).ready(function(){
# $( ".group-members li:nth-child(3)" ).find('span a').text('Asociacion Colombiana de Medios de Informacion')
# setTimeout(function(){
# $('.modulo_seleccionados_recurso img[data-original]').each(function(){
# $(this).attr('data-original', $(this).attr('data-original').replace('files/','/files/'));
# window.lazyLoad()
# })
# $('.descubre_noticias').find('.dataurl').each(function(){
# $(this).attr('href', $(this).attr('href').replace(/(^\/\/)/,'/'));
# }); }, 6000);
# if(!$('#sas_9343').length){
# var _formatId = 9343;
# $('.ads-end-article').append('<di'+'v class="ad-unit" id="sas_9343" width="0" height="0"><\/di'+'v>');
# if($('.bbc-mundo').length || $('.articulo.article.default').length==0){
# return;
# }
# sas.cmd.push(function() {
# sas.call("std", {
# siteId: sas_siteId, pageId: sas_pageId, formatId: _formatId, target: sas_target , tagId: "sas_"+_formatId
# });
# });
# }
# });
#       </script>
#      </div>
#      <div class="" id="p15871-m520-5-521">
#       <script type="text/javascript">
#        if (location.pathname === "/archivo/documento/CMS-13064037" ||
# location.pathname === "/archivo/documento/CMS-1997146" || location.pathname === "/archivo/documento/CMS-724071" || location.pathname === "/archivo/documento/CMS-455667" || location.pathname === "/archivo/documento/CMS-13472815") { sas.cmd.length = 0 }
#       </script>
#      </div>
#      <div class="" id="p15871-m526-6-527">
#       <style>
#        .section-home header nav .menu_principal2 ul li.unidad-investigativa{padding: 14px 14px 18px 0;}
#       </style>
#      </div>
#      <div class="" id="p15871-m532-7-533">
#       <style>
#        .qc-cmp-deprecation-messaging{
# display:none
# }
#       </style>
#      </div>
#      <div class="" id="p15871-m538-8-539">
#       <style>
#        header .top-contenedor .topbar .cliente #suscribase-header, header .top-contenedor .topbar3 .cliente #suscribase-header{background: #27AE60;}@media screen and (max-width: 768px){.m-registro-login .btn_subscription{font-size:0;background: #27AE60;}}.m-registro-login .btn_subscription::before{content: "suscribirme"; font-size: 15px;}
#       </style>
#      </div>
#      <div class="" id="p15871-m544-9-545">
#       <style>
#        .podcast.wf-editor .recomendado.cont-mask .reproductor-podcast::before{
# display:none;
# }
#       </style>
#      </div>
#      <div class="" id="p15871-m701-10-702">
#       <style>
#        .search-page [id*="afscontainer"] {
# margin: 30px auto;
# max-width: 1000px;
# }
# @media screen and (max-width: 767px) {
# .search-page [id*="afscontainer"] {
# margin: 20px auto;
# max-width: 100%;
# }
# }
#       </style>
#      </div>
#     </div>
#    </div>
#    <div class="content_grid content_grid_header">
#     <header class="header-home header-blanco" id="header_new">
#      <div class="top-contenedor">
#       <div class="top_bar topbar">
#        <!--Buscador -->
#        <a class="buscador-header-container">
#         <span class="buscador-icon">
#         </span>
#         <form action="/buscar" class="buscador-form" method="GET" name="search_form" style="display: none">
#          <span class="buscador-icon">
#          </span>
#          <input autocomplete="off" class="search bloque" name="q" placeholder="Noticias de Colombia y el Mundo" type="text"/>
#         </form>
#        </a>
#        <!-- Menu de secciones -->
#        <div class="box-sections">
#         <strong class="hamburguesa-icon">
#          <span>
#           Secciones
#          </span>
#         </strong>
#         <div class="content-sections">
#          <!--Buscador -->
#          <a class="buscador-header-container-sections">
#           <span class="buscador-icon">
#           </span>
#           <form action="/buscar" class="buscador-form" method="GET" name="search_form" style="display: none">
#            <span class="buscador-icon">
#            </span>
#            <input autocomplete="off" class="search bloque" name="q" placeholder="Noticias de Colombia y el Mundo" type="text"/>
#           </form>
#          </a>
#          <ul>
#           <li>
#            <a class="suscribase-header" href="https://www.eltiempo.com/suscripcion-digital">
#             <span class="suscribase">
#              Suscríbete x $900
#              <span class="texto-light">
#               1er mes
#              </span>
#             </span>
#            </a>
#            <a class="noticia upper-text dtm-profiling-header abrir-noticias">
#             mis noticias
#            </a>
#           </li>
#           <li itemprop="name">
#            <a href="/opinion" itemprop="url">
#             opinión
#            </a>
#            <span class="arrow">
#            </span>
#            <ul>
#             <li itemprop="name">
#              <a href="/opinion" itemprop="url">
#               columnistas
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/opinion/editorial" itemprop="url">
#               editorial
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/opinion/caricaturas" itemprop="url">
#               caricaturas
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="http://blogs.eltiempo.com/" itemprop="url">
#               blogs
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#            </ul>
#           </li>
#           <li itemprop="name">
#            <a href="/colombia" itemprop="url">
#             colombia
#            </a>
#            <span class="arrow">
#            </span>
#            <ul>
#             <li itemprop="name">
#              <a href="/bogota" itemprop="url">
#               bogotá
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/colombia/medellin" itemprop="url">
#               medellín
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/colombia/barranquilla" itemprop="url">
#               barranquilla
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/colombia/cali" itemprop="url">
#               cali
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/colombia/santander" itemprop="url">
#               santander
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#            </ul>
#           </li>
#           <li itemprop="name">
#            <a href="/bogota" itemprop="url">
#             bogotá
#            </a>
#            <span class="arrow">
#            </span>
#           </li>
#           <li itemprop="name">
#            <a href="/mundo" itemprop="url">
#             internacional
#            </a>
#            <span class="arrow">
#            </span>
#            <ul>
#             <li itemprop="name">
#              <a href="/mundo/latinoamerica" itemprop="url">
#               latinoamérica
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/mundo/venezuela" itemprop="url">
#               venezuela
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/mundo/eeuu-y-canada" itemprop="url">
#               eeuu y canadá
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/mundo/europa" itemprop="url">
#               europa
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/mundo/africa" itemprop="url">
#               África
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/mundo/medio-oriente" itemprop="url">
#               medio oriente
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/mundo/asia" itemprop="url">
#               asia
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/mundo/mas-regiones" itemprop="url">
#               más regiones
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#            </ul>
#           </li>
#           <li itemprop="name">
#            <a href="/politica" itemprop="url">
#             política
#            </a>
#            <span class="arrow">
#            </span>
#            <ul>
#             <li itemprop="name">
#              <a href="/politica/gobierno" itemprop="url">
#               gobierno
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/politica/congreso" itemprop="url">
#               congreso
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/politica/proceso-de-paz" itemprop="url">
#               proceso de paz
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/politica/partidos-politicos" itemprop="url">
#               partidos políticos
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#            </ul>
#           </li>
#           <li itemprop="name">
#            <a href="/justicia" itemprop="url">
#             justicia
#            </a>
#            <span class="arrow">
#            </span>
#            <ul>
#             <li itemprop="name">
#              <a href="/justicia/cortes" itemprop="url">
#               cortes
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/justicia/conflicto-y-narcotrafico" itemprop="url">
#               conflicto y narcotráfico
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/justicia/investigacion" itemprop="url">
#               investigación
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/justicia/delitos" itemprop="url">
#               delitos
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/justicia/servicios" itemprop="url">
#               servicios
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/justicia/jep-colombia" itemprop="url">
#               jurisdicción especial paz
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#             <li itemprop="name">
#              <a href="/justicia/paz-y-derechos-humanos" itemprop="url">
#               paz y derechos humanos
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
#            </ul>
#           </li>
#           <li itemprop="name">
#            <a href="/economia" itemprop="url">
#             economía
#            </a>
#            <span class="arrow">
#            </span>
#            <ul>
#             <li itemprop="name">
#              <a href="/economia/finanzas-personales" itemprop="url">
#               finanzas personales
#              </a>
#              <span class="arrow">
#              </span>
#             </li>
# ...
#              <meta content="https://www.eltiempo.com/bundles/eltiempocms/images/el-tiempo/logo-el-tiempo-azul.jpg" itemprop="url"/>
#              <meta content="600" itemprop="width"/>
#              <meta content="60" itemprop="height"/>
#             </div>
#             <meta content="EL TIEMPO" itemprop="name"/>
#             <meta content="https://www.eltiempo.com" itemprop="url"/>
#            </div>
#            <div class="oculto" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#             <meta content="570" itemprop="width"/>
#             <meta content="380" itemprop="height"/>
#             <meta content="https://www.eltiempo.com/bundles/eltiempocms/images/default.jpg" itemprop="url"/>
#            </div>
#           </article>
#           <article class="simple" dtm-name="Contenido19" id="p578531-m1798-2-1799" itemscope="" itemtype="https://schema.org/NewsArticle">
#            <div class="category-published">
#             <a class="category page-link justicia justicia--cortes" href="/justicia/cortes" id="m1803-1802-1804">
#              Cortes
#             </a>
#             <span class="published-at" id="m1809-1-1810">
#              1:45 am
#             </span>
#            </div>
#            <h3 class="title-container" itemprop="headline">
#             <a class="multimediatag page-link" href="/justicia/cortes/armando-benedetti-defensa-rechaza-extincion-de-dominio-627702">
#              <span id="m1815-2-1816">
#               Contenido Patrocinado
#              </span>
#             </a>
#             <a class="title page-link" href="/justicia/cortes/armando-benedetti-defensa-rechaza-extincion-de-dominio-627702" id="m1821-3-1822">
#              'La decisión de la Fiscalía es excesiva y abusiva': Defensa de Benedetti
#             </a>
#            </h3>
#            <meta content="2021-10-26" itemprop="datePublished"/>
#            <meta content="2021-10-25" itemprop="dateModified"/>
#            <meta itemid="https://www.eltiempo.com/justicia/cortes/armando-benedetti-defensa-rechaza-extincion-de-dominio-627702" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"/>
#            <span class="oculto" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
#             <span itemprop="name">
#              Alejandra Bonilla Mora
#             </span>
#            </span>
#            <div class="oculto" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">
#             <div itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#              <meta content="https://www.eltiempo.com/bundles/eltiempocms/images/el-tiempo/logo-el-tiempo-azul.jpg" itemprop="url"/>
#              <meta content="600" itemprop="width"/>
#              <meta content="60" itemprop="height"/>
#             </div>
#             <meta content="EL TIEMPO" itemprop="name"/>
#             <meta content="https://www.eltiempo.com" itemprop="url"/>
#            </div>
#            <div class="oculto" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#             <meta content="570" itemprop="width"/>
#             <meta content="380" itemprop="height"/>
#             <meta content="https://www.eltiempo.com/bundles/eltiempocms/images/default.jpg" itemprop="url"/>
#            </div>
#           </article>
#           <article class="simple contenido-exclusivo-icon" dtm-name="Contenido20" id="p578531-m1829-3-1830" itemscope="" itemtype="https://schema.org/NewsArticle">
#            <div class="category-published">
#             <a class="category page-link politica politica--gobierno" href="/politica/gobierno" id="m1834-1833-1835">
#              Gobierno
#             </a>
#             <span class="published-at" id="m1840-1-1841">
#              6:49 am
#             </span>
#            </div>
#            <h3 class="title-container" itemprop="headline">
#             <a class="multimediatag page-link" href="/politica/gobierno/canciller-las-razones-de-la-visita-del-fiscal-de-la-cpi-a-colombia-627851">
#              <span id="m1846-2-1847">
#               Galería
#              </span>
#             </a>
#             <a class="title page-link" href="/politica/gobierno/canciller-las-razones-de-la-visita-del-fiscal-de-la-cpi-a-colombia-627851" id="m1852-3-1853">
#              Las razones de la visita del Fiscal de la CPI a Colombia
#             </a>
#            </h3>
#            <meta content="2021-10-26" itemprop="datePublished"/>
#            <meta content="2021-10-26" itemprop="dateModified"/>
#            <meta itemid="https://www.eltiempo.com/politica/gobierno/canciller-las-razones-de-la-visita-del-fiscal-de-la-cpi-a-colombia-627851" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"/>
#            <span class="oculto" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
#             <span itemprop="name">
#              Jorge Meléndez
#             </span>
#            </span>
#            <div class="oculto" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">
#             <div itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#              <meta content="https://www.eltiempo.com/bundles/eltiempocms/images/el-tiempo/logo-el-tiempo-azul.jpg" itemprop="url"/>
#              <meta content="600" itemprop="width"/>
#              <meta content="60" itemprop="height"/>
#             </div>
#             <meta content="EL TIEMPO" itemprop="name"/>
#             <meta content="https://www.eltiempo.com" itemprop="url"/>
#            </div>
#            <div class="oculto" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#             <meta content="570" itemprop="width"/>
#             <meta content="380" itemprop="height"/>
#             <meta content="https://www.eltiempo.com/bundles/eltiempocms/images/default.jpg" itemprop="url"/>
#            </div>
#           </article>
#          </div>
#          <div class="ad-container">
#           <div class="ad_sas_pauta_desktop" id="sas_9611">
#           </div>
#           <div class="ad_sas_pauta_tablet" id="sas_9611">
#           </div>
#          </div>
#         </div>
#        </section>
#       </div>
#      </div>
#     </div>
#     <div class="progressive-loading-view">
#     </div>
#     <div class="progressive-loading" data-block="1" data-size="2">
#     </div>
#    </div>
#    <div class="content_grid content-grid-footer">
#     <footer id="new_footer">
#      <div class="mainFooter">
#       <div class="mainFooter_principal">
#        <div class="mainFooter_principalContent">
#         <div class="mainFooter_principal_channels">
#          <div class="mainFooter_principal_channels_main">
#           <figure class="mainFooter_principal_channels_main_logo">
#            <a href="/">
#             <img alt="" data-original="/images/eltiempo_logo.png" src="..."/>
#            </a>
#           </figure>
#          </div>
#          <div class="mainFooter_principal_channels_social">
#           <div class="mainFooter_principal_channels_social_title">
#            SÍGUENOS EN:
#           </div>
#           <ul class="mainFooter_principal_channels_social_items">
#            <li class="mainFooter_principal_channels_social_items_fb">
#             <a href="https://www.facebook.com/eltiempo" target="_blank">
#             </a>
#            </li>
#            <li class="mainFooter_principal_channels_social_items_tw">
#             <a href="https://twitter.com/eltiempo" target="_blank">
#             </a>
#            </li>
#            <li class="mainFooter_principal_channels_social_items_yt">
#             <a href="https://www.youtube.com/user/ElTiempoPLAY" target="_blank">
#             </a>
#            </li>
#            <li class="mainFooter_principal_channels_social_items_in">
#             <a href="https://www.instagram.com/eltiempo/" target="_blank">
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="mainFooter_principal_menu">
#          <span class="arrow">
#          </span>
#          <ul class="footer-menu">
#           <li class="link first" itemprop="name">
#            <a href="/ayuda" itemprop="url">
#             Ayuda
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="/politica-privacidad" itemprop="url">
#             Aviso de Privacidad
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="/terminos-condiciones" itemprop="url">
#             Términos y condiciones
#            </a>
#           </li>
#           <li class="link" itemprop="name">
#            <a href="/politica-de-cookies" itemprop="url">
#             Política de Cookies
#            </a>
#           </li>
#           <li class="link" itemprop="name">
#            <a href="/mapa-sitio" itemprop="url">
#             Mapa del Sitio
#            </a>
#           </li>
#           <li class="btn-conoce link" itemprop="name">
#            <a href="javascript:void(0)" itemprop="url">
#             Conoce Nuestros Portales
#            </a>
#           </li>
#           <li class="link" itemprop="name">
#            <a href="/servicio-al-cliente" itemprop="url">
#             Servicio al Cliente
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="https://www.eltiempocasaeditorial.com/linea-etica" itemprop="url">
#             Línea Ética
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="http://www.clubvivamos.com/" itemprop="url">
#             Club de suscriptores Vivamos
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="/rss" itemprop="url">
#             RSS
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="https://cursos.eltiempo.com/" itemprop="url">
#             Cursos El Tiempo
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="https://www.eltiempocasaeditorial.com/" itemprop="url">
#             Casa Editorial El Tiempo
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="https://tienda.eltiempo.com/" itemprop="url">
#             Colecciones El Tiempo
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="http://www.audienciadigital.co/" itemprop="url">
#             Paute con nosotros
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="http://www.elempleo.com/sitios-empresariales/colombia/el-tiempo-casa-editorial/" itemprop="url">
#             Trabaje con nosotros
#            </a>
#           </li>
#           <li class="link" itemprop="name">
#            <a href="/publicidad-politica-pagada" itemprop="url">
#             Publicidad Política Pagada
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="https://seg.eltiempo.com/suscripciones/impreso/eltiempodigital" itemprop="url">
#             Suscribirse
#            </a>
#           </li>
#           <li class="link external last" itemprop="name">
#            <a href="https://www.eltiempocasaeditorial.com/solicitud-reversion-de-pago" itemprop="url">
#             Reversión de Pago
#            </a>
#           </li>
#          </ul>
#          <div class="mainFooter_principal_menu_members">
#           <div class="mainFooter_principal_menu_members_title">
#            MIEMBRO DE:
#           </div>
#           <ul class="mainFooter_principal_menu_members_items">
#            <li>
#             <figure>
#              <img alt="" src="/images/footer/img_1.png"/>
#             </figure>
#             <div>
#              Grupo de Diarios de América
#             </div>
#            </li>
#            <li>
#             <a href="https://ami.org.co/" target="_blank">
#              <figure>
#               <img alt="" src="/images/footer/img_3.png"/>
#              </figure>
#             </a>
#             <div>
#              <a href="https://ami.org.co/" target="_blank">
#               Asociación Colombiana de Medios de Información
#              </a>
#             </div>
#            </li>
#            <li>
#             <figure>
#              <img alt="" src="/images/footer/img_2.png"/>
#             </figure>
#             <div>
#              Interactive Advertisement Bureau
#             </div>
#            </li>
#            <li>
#             <a href="https://www.sic.gov.co/" target="_blank">
#              <figure>
#               <img alt="" src="/images/footer/img_4.png"/>
#              </figure>
#             </a>
#             <div>
#              <a href="https://www.sic.gov.co/" target="_blank">
#               Superintendencia de Industria y Comercio
#              </a>
#             </div>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="mainFooter_otherPortals">
#        <div class="mainFooter_otherPortalsContent">
#         <span class="arrow">
#         </span>
#         <ul class="footer-portals1-menu">
#          <li class="link external first" itemprop="name">
#           <a href="http://portafolio.co" itemprop="url">
#            Noticias de economía
#            <span>
#             - portafolio.co
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://www.elempleo.com/co/ofertas-empleo/" itemprop="url">
#            Empleos en Colombia
#            <span>
#             - elempleo.com
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://www.futbolred.com" itemprop="url">
#            Noticias de fútbol
#            <span>
#             - futbolred.com
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://www.revistadonjuan.com" itemprop="url">
#            Fotos y modelos
#            <span>
#             - revistadonjuan.com
#            </span>
#           </a>
#          </li>
#          <li class="link external last" itemprop="name">
#           <a href="http://www.diarioadn.co" itemprop="url">
#            Noticias de Actualidad
#            <span>
#             - diarioadn.co
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="mainFooter_disclaimer">
#        <div class="mainFooter_disclaimerContent">
#         <div class="disclaimer-content">
#          <p id="p18613-m378-377-379">
#           COPYRIGHT © 2021 EL TIEMPO Casa Editorial NIT. 860.001.022-7. Prohibida su reproducción total o parcial, así como su traducción a cualquier idioma sin autorización escrita de su titular.
#           <br/>
#           ELTIEMPO.com todas las noticias principales de Colombia y el Mundo
#          </p>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#    </div>
#    <div class="dictum-box" id="dictum-box">
#    </div>
#   </div>
#   <script type="text/javascript">
#    var sas_pageId = "152163";
#   </script>
#   <script defer="defer" src="//ced.sascdn.com/tag/484/smart.js" type="text/javascript">
#   </script>
#   <script async="" type="text/javascript">
#    /** CONFIGURATION START **/
# _sf_async_config.sections = 'home'; //CHANGE THIS
# _sf_async_config.authors = ''; //CHANGE THIS
# var _cbq = window._cbq = (window._cbq || []);
# if(getUserName()){
# if(getCmsCookie('suscriptor') == "true"){
# _cbq.push(['_acct', 'paid']);
# }else
# _cbq.push(['_acct', 'lgdin']);
# }
# else{
# _cbq.push(['_acct', 'anon']);
# }
# /** CONFIGURATION END **/
# (function() {
# function loadChartbeat() {
# var e = document.createElement('script');
# var n = document.getElementsByTagName('script')[0];
# e.type = 'text/javascript';
# e.async = true;
# e.src = '//static.chartbeat.com/js/chartbeat.js';
# n.parentNode.insertBefore(e, n);
# }
# loadChartbeat();
# })();
#   </script>
#   <!-- begin Convert Experiences code-->
#   <!-- <script defer="defer" type="text/javascript" src="//cdn-3.convertexperiments.com/js/10022306-10021161.js"></script>-->
#   <!-- end Convert Experiences code -->
#   <script defer="defer" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js">
#   </script>
#  </body>
# </html>

# %%
list_tag = []
for tag in soup.find_all():
    list_tag.append(tag.name)
    
tag_count = {}

for tag in list_tag:
    if tag in tag_count:
        tag_count[tag] = tag_count[tag] + 1
    else:
        tag_count[tag] = 1
        
tag_count
# Out:
# {'html': 1,
#  'head': 1,
#  'script': 35,
#  'meta': 662,
#  'link': 17,
#  'title': 2,
#  'div': 633,
#  'body': 1,
#  'noscript': 2,
#  'iframe': 4,
#  'style': 13,
#  'header': 1,
#  'a': 423,
#  'span': 346,
#  'form': 4,
#  'input': 24,
#  'strong': 5,
#  'ul': 22,
#  'li': 177,
#  'figure': 26,
#  'img': 50,
#  'p': 46,
#  'svg': 2,
#  'desc': 1,
#  'g': 1,
#  'polyline': 5,
#  'path': 3,
#  'polygon': 1,
#  'nav': 1,
#  'section': 17,
#  'br': 7,
#  'u': 3,
#  'h1': 3,
#  'h2': 10,
#  'article': 48,
#  'h3': 58,
#  'picture': 19,
#  'source': 17,
#  'label': 4,
#  'button': 2,
#  'footer': 1}

# %%
soup.h3.text
# Out:
# '\n\nEn Vivo\nCon nueva matriz, Avianca emergerá del Capítulo 11'
